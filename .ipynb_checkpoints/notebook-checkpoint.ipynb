# %% [markdown]
# ## Imports: <a class = "anchor" id = "imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %% [markdown]
# ## Data: <a class = "anchor" id = "data"></a>

# %%
df = pd.read_csv("stats.csv",).rename(columns = {" first_name" : "first_name"})
df["first_name"] = df["first_name"].str.strip()
df["full_name"] = df["first_name"] + " " + df["last_name"]
df.insert(0, "full_name", df.pop("full_name"))
df.drop(columns = "Unnamed: 38", inplace = True)
df["slash_line"] = df["batting_avg"].astype(str).map(lambda x: x[1:5]) + "/" +\
                   df["on_base_percent"].astype(str).map(lambda x: x[1:5]) + "/" +\
                   df["slg_percent"].astype(str).map(lambda x: x[1:5]) + "/" +\
                   df["on_base_plus_slg"].astype(str).map(lambda x: x[1:5])

# %%
df.head()
# Out:
#           full_name  last_name first_name  player_id  year  player_age  b_ab  \
# 0    Miguel Cabrera    Cabrera     Miguel     408234  2021          38   296
# 1   Nelson Cruz Jr.   Cruz Jr.     Nelson     443558  2021          41   313
# 2     David Peralta    Peralta      David     444482  2021          34   332
# 3  Charlie Blackmon   Blackmon    Charlie     453568  2021          35   324
# 4  Andrew McCutchen  McCutchen     Andrew     457705  2021          35   323
#
#    b_total_pa  b_total_hits  b_single  ...  xwoba   xobp   xiso  wobacon  \
# 0         326            73        55  ...  0.306  0.291  0.179    0.359
# 1         366            89        54  ...  0.384  0.364  0.250    0.431
# 2         370            84        52  ...  0.295  0.314  0.106    0.337
# 3         370            88        64  ...  0.352  0.372  0.134    0.337
# 4         393            77        43  ...  0.361  0.368  0.201    0.401
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   full_name                137 non-null    object
#  1   last_name                137 non-null    object
#  2   first_name               137 non-null    object
#  3   player_id                137 non-null    int64
#  4   year                     137 non-null    int64
#  5   player_age               137 non-null    int64
#  6   b_ab                     137 non-null    int64
#  7   b_total_pa               137 non-null    int64
#  8   b_total_hits             137 non-null    int64
#  9   b_single                 137 non-null    int64
#  10  b_double                 137 non-null    int64
#  11  b_triple                 137 non-null    int64
#  12  b_home_run               137 non-null    int64
#  13  b_strikeout              137 non-null    int64
# ...

# %% [markdown]
# ## EDA: <a class = "anchor" id = "eda"></a>

# %%
# Relationship between exit velocity and launch angle
x = df["exit_velocity_avg"]
y = df["launch_angle_avg"]


plt.figure(figsize = (12,8))
plt.scatter(x,y, c = "b")

z = np.polyfit(x,y,1)
p = np.poly1d(z)
plt.plot(x, p(x), "r--")

plt.title("2021 Avg. Exit Velocity vs Avg. Launch Angle (as of 7/29/21)")
plt.xlabel("Average Exit Velocity")
plt.ylabel("Average Launch Angle")

a = df.loc[df["exit_velocity_avg"] == min(df["exit_velocity_avg"]), ["full_name", "exit_velocity_avg", "launch_angle_avg"]].reset_index()
plt.annotate(a["full_name"][0],
             (a["exit_velocity_avg"][0], a["launch_angle_avg"][0]),
             ha = "center",
             va = "bottom")

b = df.loc[df["exit_velocity_avg"] == max(df["exit_velocity_avg"]), ["full_name", "exit_velocity_avg", "launch_angle_avg"]].reset_index()
plt.annotate(b["full_name"][0],
             (b["exit_velocity_avg"][0], b["launch_angle_avg"][0]),
             ha = "center",
             va = "bottom")

c = df.loc[df["launch_angle_avg"] == min(df["launch_angle_avg"]), ["full_name", "exit_velocity_avg", "launch_angle_avg"]].reset_index()
plt.annotate(c["full_name"][0],
             (c["exit_velocity_avg"][0], c["launch_angle_avg"][0]),
             ha = "center",
             va = "bottom")

d = df.loc[df["launch_angle_avg"] == max(df["launch_angle_avg"]), ["full_name", "exit_velocity_avg", "launch_angle_avg"]].reset_index()
plt.annotate(d["full_name"][0],
             (d["exit_velocity_avg"][0], d["launch_angle_avg"][0]),
             ha = "center",
             va = "bottom");
# plt.savefig("plot.png");

# %%
players = ["Raimel Tapia", "Adam Duvall"]
cols = ["full_name", "exit_velocity_avg", "launch_angle_avg", "slash_line", "b_home_run"]

df.loc[df["full_name"].isin(players), cols]
# Out:
#        full_name  exit_velocity_avg  launch_angle_avg           slash_line  \
# 62   Adam Duvall               90.3              24.0  .228/.276/.478/.755
# 71  Raimel Tapia               86.5              -3.1   .286/.34/.385/.725
#
#     b_home_run
# 62          22
# 71           5

# %%
# df.loc[df["full_name"].isin(players), cols].to_markdown()

# %% [markdown]
# - Adam Duvall has the highest average launch angle, while Raimel Tapia has the lowest.

# %%
players = ["David Fletcher", "Aaron Judge"]
cols = ["full_name", "exit_velocity_avg", "launch_angle_avg", "slash_line", "b_home_run"]

df.loc[df["full_name"].isin(players), cols]
# Out:
#           full_name  exit_velocity_avg  launch_angle_avg           slash_line  \
# 54      Aaron Judge               95.9              10.0   .283/.377/.52/.898
# 118  David Fletcher               82.5               7.8  .305/.328/.379/.708
#
#      b_home_run
# 54           21
# 118           2

# %%
# df.loc[df["full_name"].isin(players), cols].to_markdown()

# %% [markdown]
# - Aaron Judge has the highest average exit velocity, while David Fletcher has the lowest.
